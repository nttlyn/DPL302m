# %%
import cv2
import os
import time
from ultralytics import YOLO
from IPython.display import display, Image
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# !pip install ultralytics==8.0.20
from IPython import display
display.clear_output()
import ultralytics

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="LnOBTMVYigDpNXXUcaMy")
project = rf.workspace("helmetdetection-kshhr").project("helmet_v3")
dataset = project.version(1).download("yolov8")

# %%
# %cd {HOME}

from ultralytics import YOLO

model= YOLO()/content/dat

model.train(data='/content/gdrive/MyDrive/DPL302m/dataset/Hung_data/lable/vehicle_labeled', epochs=75)

# %%
from ultralytics import YOLO

data_path = '/content/gdrive/MyDrive/DPL302m/dataset/Hung_data/lable/vehicle_2_labeled/461.txt'
model = YOLO()
model.train(data=data_path, epochs=75)

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train2/val_batch0_pred.jpg', width=600)
